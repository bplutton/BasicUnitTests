# %% [markdown]
# <a href="https://colab.research.google.com/github/bplutton/BasicUnitTests/blob/main/February_25%2C_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Generate a list of 1,000 random integers between 1 and 100 (inclusive)
random_integers = [random.randint(1, 100) for _ in range(1000)]

print(f"Generated {len(random_integers)} random integers.")
print("First 10 integers:", random_integers[:10])
# Out:
# Generated 1000 random integers.
# First 10 integers: [38, 17, 55, 82, 75, 78, 48, 14, 77, 56]

# %%
def seq_search(a_list, item):
    pos = 0
    while pos < len(a_list):
        if a_list[pos] == item:
            return True
        pos = pos + 1
    return False

# %%
def ord_seq_search(a_list, item):
    pass
    # TODO: Finish this definition
